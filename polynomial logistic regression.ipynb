# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('datasets/ushape.csv',header=None)
x=data.iloc[:,:2]
y=data.iloc[:,2]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
x,y
# Out:
# (           0         1
#  0   0.031595  0.986988
#  1   2.115098 -0.046244
#  2   0.882490 -0.075756
#  3  -0.055144 -0.037332
#  4   0.829545 -0.539321
#  ..       ...       ...
#  95  1.699453  0.587720
#  96  0.218623 -0.652521
#  97  0.952914 -0.419766
#  98 -1.318500  0.423112
#  99 -1.296818  0.184147
#
#  [100 rows x 2 columns],
#  0     0.0
#  1     1.0
#  2     0.0
#  3     1.0
#  4     1.0
#       ...
#  95    1.0
#  96    1.0
#  97    1.0
#  98    0.0
#  99    0.0
#  Name: 2, Length: 100, dtype: float64)

# %%
sns.scatterplot(x=x[0],y=x[1],c=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
m1=LogisticRegression()
m1.fit(x_train,y_train)
m=-m1.coef_[0,0]/m1.coef_[0,1]
b=-m1.intercept_/m1.coef_[0,1]

# %%
sns.scatterplot(x=x[0],y=x[1],c=y)
sns.lineplot(x=np.linspace(-2,3,100),y=(m*np.linspace(-2,3,100)+b).flatten())
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(3)
x_train_new=poly.fit_transform(x_train)
x_test_new=poly.fit_transform(x_test)

# %%
m2=LogisticRegression()
m2.fit(x_train_new,y_train)
# Out:
# LogisticRegression()
